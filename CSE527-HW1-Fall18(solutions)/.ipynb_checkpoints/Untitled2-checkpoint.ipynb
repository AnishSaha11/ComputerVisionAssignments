# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
img = cv2.imread("/Users/anishsaha/Downloads/CSE527-HW1-Fall18/SourceImages/sunset.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

hist,bins=np.histogram(img_hsv,256,[0,255])
cdf=hist.cumsum()
cdf_normal = cdf*hist.max()/cdf.max()
cdf_m = (cdf_normal - cdf_normal.min())*255/(cdf_normal.max()-cdf_normal.min())

img2 = cdf_m[img_rgb]

histEQ,binsEQ=np.histogram(img2,256,[0,255])
cdfEQ=histEQ.cumsum()
cdfEQ_normal = cdfEQ*histEQ.max()/cdfEQ.max()
plt.figure(figsize=(30,30))

plt.subplot(3,3,1)
plt.imshow(img_rgb)
plt.title("original")

plt.subplot(3,3,2)
plt.imshow(img_gray)
plt.title("hsv")

plt.subplot(3,3,3)
plt.imshow(img2)
plt.title("equalized")

plt.subplot(3,3,4)
plt.plot(cdf_normal,color='r')
plt.hist(img_hsv.flatten(),256,[0,256], color = 'b')
plt.title("plotOriginal")

plt.subplot(3,3,5)
plt.plot(cdfEQ_normal,color='r')
plt.hist(img2.flatten(),256,[0,256], color = 'b')
plt.title("plotEqualized")
plt.show
# Out:
# (256,)
# <function matplotlib.pyplot.show>
